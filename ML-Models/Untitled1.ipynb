# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("raihan150146/insurance-dataset-for-logistic-regression")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import kagglehub
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("raihan150146/insurance-dataset-for-logistic-regression")
#
# ModuleNotFoundError: No module named 'kagglehub'
