# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Dataset
X = np.array([[1],[2],[3],[4],[5],[6],[7]])  # hours
y = np.array([35,40,50,60,65,75,85])        # marks

# Model
model = LinearRegression()
model.fit(X, y)

# Predictions
y_pred = model.predict(X)

print("Slope (m):", model.coef_)
print("Intercept (b):", model.intercept_)
print("MSE:", mean_squared_error(y, y_pred))
print("R2 Score:", r2_score(y, y_pred))
X,y
# Out:
# Slope (m): [8.39285714]
# Intercept (b): 25.000000000000007
# MSE: 1.9132653061224487
# R2 Score: 0.9932553956834532
# (array([[1],
#         [2],
#         [3],
#         [4],
#         [5],
#         [6],
#         [7]]),
#  array([35, 40, 50, 60, 65, 75, 85]))

# %%
plt.figure()
plt.scatter(X, y, marker = 'o', label = 'Actual Output')
plt.plot(X, y_pred, label = 'predicted ouptut')
plt.xlabel("study hours")
plt.ylabel("marks")
plt.title("linear regression: actual vs predicted")
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np
# Data
X = np.array([[1],[2],[3],[4],[5],[6],[7]])
y = np.array([0,0,1,1,1,1,1])  # pass/fail

model = LogisticRegression()
model.fit(X, y)

# Predictions

x_range = np.linspace(0, 8, 100).reshape(-1,1)
y_prob = model.predict_proba(x_range)[:, 1]
"""pred_class = model.predict(X)
pred_prob = model.predict_proba(X)

print("Predicted Probabilities:\n", pred_prob)
print("Predicted Classes:", pred_class)
print("Accuracy:", accuracy_score(y, pred_class))
print("Confusion Matrix:\n", confusion_matrix(y, pred_class))"""
# Out:
# 'pred_class = model.predict(X)\npred_prob = model.predict_proba(X)\n\nprint("Predicted Probabilities:\n", pred_prob)\nprint("Predicted Classes:", pred_class)\nprint("Accuracy:", accuracy_score(y, pred_class))\nprint("Confusion Matrix:\n", confusion_matrix(y, pred_class))'

# %%
plt.figure()
plt.scatter(X, y, marker='o', label='Actual Output')
plt.plot(x_range, y_prob, label='Predicted Probability')
plt.axhline(0.5, linestyle='--', label='Decision Boundary (0.5)')
plt.xlabel("study hours")
plt.ylabel("Probability of passing")
plt.title("logistic regression: actual vs predicted")
plt.legend()
plt.show()
