# %% [markdown]
# # Title (big)
# ## Section
# ### Subsection
# #### Small heading

# %% [markdown]
# **bold text**
# *italic text*
# ***bold + italic***
# ~~strike text~~

# %% [markdown]
# - Item 1
# - Item 2
# - Item 3

# %% [markdown]
# - Data Cleaning
#   - Remove nulls
#   - Encode labels
# - Model

# %% [markdown]
# 1. Load dataset
# 2. Clean data
# 3. Train model
# 4. Evaluate

# %% [markdown]
# Use `train_test_split()` to split the data.

# %% [markdown]
# ```python
# import pandas as pd
# df = pd.read_csv("data.csv")
# ```

# %% [markdown]
# ---

# %% [markdown]
# [Open Kaggle](https://www.kaggle.com)

# %% [markdown]
# ![Title](image.png)

# %% [markdown]
# ![Heart](https://upload.wikimedia.org/wikipedia/commons/6/6f/Heart_diagram-en.svg)

# %% [markdown]
# | Feature | Meaning |
# |--------|---------|
# | age | Age of patient |
# | sex | Gender |
# | cp | Chest pain |

# %% [markdown]
# > This dataset has class imbalance.

# %% [markdown]
# - [x] Data loaded
# - [x] Cleaned dataset
# - [ ] Train model
# - [ ] Tune hyperparameters

# %% [markdown]
# $y = mx + c$

# %% [markdown]
# $$
# MSE = \frac{1}{n}\sum (y - \hat{y})^2
# $$

# %% [markdown]
# <span style="color:green">Model improved after scaling</span>

# %% [markdown]
# <h2 style="text-align:center;">Heart Disease Prediction</h2>

# %% [markdown]
# <details>
# <summary>Click to see preprocessing steps</summary>
#
# - Removed duplicates
# - Filled missing values
# - Encoded categorical columns
#
# </details>

# %% [markdown]
# # 📊 Project Title
#
# ## 🎯 Objective
# Explain what you are solving.
#
# ---
#
# ## 📂 Dataset
# Describe dataset briefly.
#
# ---
#
# ## 🧹 Preprocessing
# Explain cleaning steps.
#
# ---
#
# ## 🤖 Model
# Explain algorithm used.
#
# ---
#
# ## 📈 Results
# Write accuracy and findings.
